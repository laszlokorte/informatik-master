# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def sgd(degree, x, y):
    theta = np.random.rand(degree)
    for i in range(0, len(x)):
        theta = theta + alpha(y[i]- h(x[i])) * x[i]

# %%
# Data points
points_x = np.random.rand(100)
points_y = np.sin(2 * math.pi * points_x) + np.random.uniform(-0.3, 0.3, 100)

# sin function
x = np.arange(0, 1, 0.01)
sin = np.sin(x * 2 * math.pi)

# %%
plt.scatter(points_x, points_y, c='blue')
plt.plot(x, sin, c='red')
